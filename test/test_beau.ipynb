# %%
from hey_ac import HeyAC
import yaml

# %%
h = HeyAC(grammar_path = '../grammars/grammar_beau.txt')

# %%
texts = [
    'turn up the heat',
    'turn the AC off',
    'turn on the fan mode',
    'turn off the fan',
    'turn down the temperature',
    'turn down the fan',
    'swing up the air',
    'swing the AC',
    'stop the swing',
    'reduce the temperature',
    'raise the temperature',
    'pause the swing',
    'increase the humidity',
    'increase the fan speed',
    'activate fan mode',
    'increase the temperature',
    'lower the fan speed',
    'lower the air',
    'dry the room',
    'decrease the humidity',
    'turn up the temperature by 3 degrees',
    'turn on the air-conditioner', #for me
    'turn on the AC to 28 degrees',
    'turn the AC on to 25 degrees',
    'turn on the air-conditioner from 7 am to 4 p.m.',
    "turn on the air at 4 o'clock",
    "increase the temperature by 3 degrees",
    'decrease the fan speed',
    'cool down the room by 2 degrees'
]

# %%
for text in texts:
    print("="*50)
    print(text)
    print()
    print(yaml.dump(h.prune(text)))
# Out:
# ==================================================
# turn up the heat
#
# {ACT: TURN, CO: null, DIR: UP, NEG: null, NN_OBJ: null, NN_PROP: TEMPERATURE, VALUE: null,
#   VBG: null}
#
# ==================================================
# turn the AC off
#
# {ACT: TURN, CO: null, DIR: 'OFF', NEG: null, NN_OBJ: AC, NN_PROP: null, VALUE: null,
#   VBG: null}
#
# ==================================================
# turn on the fan mode
#
# {ACT: TURN, CO: null, DIR: 'ON', NEG: null, NN_OBJ: FAN, NN_PROP: MODE, VALUE: null,
#   VBG: null}
#
# ==================================================
# turn off the fan
#
# {ACT: TURN, CO: null, DIR: 'OFF', NEG: null, NN_OBJ: FAN, NN_PROP: null, VALUE: null,
#   VBG: null}
#
# ==================================================
# turn down the temperature
#
# {ACT: TURN, CO: null, DIR: DOWN, NEG: null, NN_OBJ: null, NN_PROP: TEMPERATURE, VALUE: null,
#   VBG: null}
#
# ==================================================
# turn down the fan
#
# {ACT: TURN, CO: null, DIR: DOWN, NEG: null, NN_OBJ: FAN, NN_PROP: null, VALUE: null,
#   VBG: null}
#
# ==================================================
# swing up the air
#
# {ACT: SWING, CO: null, DIR: UP, NEG: null, NN_OBJ: AC, NN_PROP: null, VALUE: null,
#   VBG: null}
#
# ==================================================
# swing the AC
#
# {ACT: SWING, CO: null, DIR: null, NEG: null, NN_OBJ: AC, NN_PROP: null, VALUE: null,
#   VBG: null}
#
# ==================================================
# stop the swing
#
# {ACT: STOP, CO: null, DIR: null, NEG: null, NN_OBJ: SWING, NN_PROP: null, VALUE: null,
#   VBG: null}
#
# ==================================================
# reduce the temperature
#
# {ACT: REDUCE, CO: null, DIR: null, NEG: null, NN_OBJ: null, NN_PROP: TEMPERATURE,
#   VALUE: null, VBG: null}
#
# ==================================================
# raise the temperature
#
# {ACT: RAISE, CO: null, DIR: null, NEG: null, NN_OBJ: null, NN_PROP: TEMPERATURE, VALUE: null,
#   VBG: null}
#
# ==================================================
# pause the swing
#
# {ACT: PAUSE, CO: null, DIR: null, NEG: null, NN_OBJ: SWING, NN_PROP: null, VALUE: null,
#   VBG: null}
#
# ==================================================
# increase the humidity
#
# {ACT: INCREASE, CO: null, DIR: null, NEG: null, NN_OBJ: null, NN_PROP: HUMIDITY, VALUE: null,
#   VBG: null}
#
# ==================================================
# increase the fan speed
#
# {ACT: INCREASE, CO: null, DIR: null, NEG: null, NN_OBJ: FAN, NN_PROP: VOLUME, VALUE: null,
#   VBG: null}
#
# ==================================================
# activate fan mode
#
# {ACT: ACTIVATE, CO: null, DIR: null, NEG: null, NN_OBJ: FAN, NN_PROP: MODE, VALUE: null,
#   VBG: null}
#
# ==================================================
# increase the temperature
#
# {ACT: INCREASE, CO: null, DIR: null, NEG: null, NN_OBJ: null, NN_PROP: TEMPERATURE,
#   VALUE: null, VBG: null}
#
# ==================================================
# lower the fan speed
#
# {ACT: LOWER, CO: null, DIR: null, NEG: null, NN_OBJ: FAN, NN_PROP: VOLUME, VALUE: null,
#   VBG: null}
#
# ==================================================
# lower the air
#
# {ACT: LOWER, CO: null, DIR: null, NEG: null, NN_OBJ: AC, NN_PROP: null, VALUE: null,
#   VBG: null}
#
# ==================================================
# dry the room
#
# {ACT: DRY, CO: null, DIR: null, NEG: null, NN_OBJ: ENVIRONMENT, NN_PROP: null, VALUE: null,
#   VBG: null}
#
# ==================================================
# decrease the humidity
#
# {ACT: DECREASE, CO: null, DIR: null, NEG: null, NN_OBJ: null, NN_PROP: HUMIDITY, VALUE: null,
#   VBG: null}
#
# ==================================================
# turn up the temperature by 3 degrees
#
# {ACT: TURN, CO: HEY_NUM, DIR: UP, NEG: null, NN_OBJ: null, NN_PROP: TEMPERATURE, VALUE: null,
#   VBG: null}
#
# ==================================================
# turn on the air-conditioner
#
# {ACT: TURN, CO: null, DIR: 'ON', NEG: null, NN_OBJ: AC, NN_PROP: null, VALUE: null,
#   VBG: null}
#
# ==================================================
# turn on the AC to 28 degrees
#
# {ACT: TURN, CO: HEY_NUM, DIR: 'ON', NEG: null, NN_OBJ: AC, NN_PROP: null, VALUE: null,
#   VBG: null}
#
# ==================================================
# turn the AC on to 25 degrees
#
# {ACT: TURN, CO: HEY_NUM, DIR: 'ON', NEG: null, NN_OBJ: AC, NN_PROP: null, VALUE: null,
#   VBG: null}
#
# ==================================================
# turn on the air-conditioner from 7 am to 4 p.m.
#
# {ACT: TURN, CO: HEY_NUM, DIR: 'ON', NEG: null, NN_OBJ: AC, NN_PROP: null, VALUE: null,
#   VBG: null}
#
# ==================================================
# turn on the air at 4 o'clock
#
# {ACT: TURN, CO: HEY_NUM, DIR: 'ON', NEG: null, NN_OBJ: AC, NN_PROP: null, VALUE: null,
#   VBG: null}
#
# ==================================================
# increase the temperature by 3 degrees
#
# {ACT: INCREASE, CO: HEY_NUM, DIR: null, NEG: null, NN_OBJ: null, NN_PROP: TEMPERATURE,
#   VALUE: null, VBG: null}
#
# ==================================================
# decrease the fan speed
#
# {ACT: DECREASE, CO: null, DIR: null, NEG: null, NN_OBJ: FAN, NN_PROP: VOLUME, VALUE: null,
#   VBG: null}
#
# ==================================================
# cool down the room by 2 degrees
#
# {ACT: COOL, CO: HEY_NUM, DIR: DOWN, NEG: null, NN_OBJ: ENVIRONMENT, NN_PROP: null,
#   VALUE: null, VBG: null}
